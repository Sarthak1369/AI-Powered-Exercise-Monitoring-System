# %%
import cv2
import mediapipe as mp
import time

class poseDetector():
    def __init__(self, mode=False, upBody = False, smooth=True, detectionCon=0.5, trackCon=0.5):
        
        self.mode = mode
        self.upBody = upBody
        self.smooth = smooth
        self.detectionCon = detectionCon
        self.trackCon = trackCon



        self.mpDraw = mp.solutions.drawing_utils
        self.mpPose = mp.solutions.pose
        self.pose = self.mpPose.Pose(self.mode, self.upBody, self.smooth, self.detectionCon, self.trackCon)
        
    def findPose(self, img, draw= True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.pose.process(imgRGB)
        if self.results.pose_landmarks:
            if draw:
                self.mpDraw.draw_landmarks(img, self.results.pose_landmarks, self.mpPose.POSE_CONNECTIONS)

        return img    
            
        
    def findPosition(self, img, draw=True):
        lmList=[]
        if self.results.pose_landmarks:
            for id, lm in enumerate(self.results.pose_landmarks.landmark):
                h, w, c = img.shape
                cx, cy = int(lm.x*w), int(lm.y*h)
                lmList.append([id,cx,cy])
                
                if draw:
                    cv2.circle(img, (cx,cy), 5, (255,0,0), cv2.FILLED)
        return lmList



def main():
    cap = cv2.VideoCapture(0)
    ptime = 0
    detector = poseDetector()
    while True:
        success , img = cap.read()
        img= detector.findPose(img)
        lmList = detector.findPosition(img)
        if len(lmList) !=0:
            print(lmList)
    
        ctime = time.time()
        fps = 1/(ctime-ptime)
        ptime = ctime
    
        cv2.putText(img,str(int(fps)),(70,50),cv2.FONT_HERSHEY_PLAIN,3,(255,0,0),3)
        cv2.imshow("image",img)
    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
    

if __name__ == "__main__":
    main()
# Out:
# Downloading model to E:\anaconda\Lib\site-packages\mediapipe/modules/pose_landmark/pose_landmark_lite.tflite
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 59
#      55     cv2.destroyAllWindows()
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[1], line 40, in main()
#      38 cap = cv2.VideoCapture(0)
#      39 ptime = 0
# ---> 40 detector = poseDetector()
#      41 while True:
#      42     success , img = cap.read()
#
# Cell In[1], line 18, in poseDetector.__init__(self, mode, upBody, smooth, detectionCon, trackCon)
#      16 self.mpDraw = mp.solutions.drawing_utils
#      17 self.mpPose = mp.solutions.pose
# ---> 18 self.pose = self.mpPose.Pose(self.mode, self.upBody, self.smooth, self.detectionCon, self.trackCon)
#
# File E:\anaconda\Lib\site-packages\mediapipe\python\solutions\pose.py:145, in Pose.__init__(self, static_image_mode, model_complexity, smooth_landmarks, enable_segmentation, smooth_segmentation, min_detection_confidence, min_tracking_confidence)
#     114 def __init__(self,
#     115              static_image_mode=False,
#     116              model_complexity=1,
#    (...)
#     120              min_detection_confidence=0.5,
#     121              min_tracking_confidence=0.5):
#     122   """Initializes a MediaPipe Pose object.
#     123
#     124   Args:
#    (...)
#     143       https://solutions.mediapipe.dev/pose#min_tracking_confidence.
#     144   """
# --> 145   _download_oss_pose_landmark_model(model_complexity)
#     146   super().__init__(
#     147       binary_graph_path=_BINARYPB_FILE_PATH,
#     148       side_inputs={
#    (...)
#     161       },
#     162       outputs=['pose_landmarks', 'pose_world_landmarks', 'segmentation_mask'])
#
# File E:\anaconda\Lib\site-packages\mediapipe\python\solutions\pose.py:97, in _download_oss_pose_landmark_model(model_complexity)
#      94 """Downloads the pose landmark lite/heavy model from the MediaPipe Github repo if it doesn't exist in the package."""
#      96 if model_complexity == 0:
# ---> 97   download_utils.download_oss_model(
#      98       'mediapipe/modules/pose_landmark/pose_landmark_lite.tflite')
#      99 elif model_complexity == 2:
#     100   download_utils.download_oss_model(
#     101       'mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite')
#
# File E:\anaconda\Lib\site-packages\mediapipe\python\solutions\download_utils.py:32, in download_oss_model(model_path)
#      30 model_url = _GCS_URL_PREFIX + model_path.split('/')[-1]
#      31 print('Downloading model to ' + model_abspath)
# ---> 32 with urllib.request.urlopen(model_url) as response, open(model_abspath,
#      33                                                          'wb') as out_file:
#      34   if response.code != 200:
#      35     raise ConnectionError('Cannot download ' + model_path +
#      36                           ' from Google Cloud Storage.')
#
# PermissionError: [Errno 13] Permission denied: 'E:\\anaconda\\Lib\\site-packages\\mediapipe/modules/pose_landmark/pose_landmark_lite.tflite'
